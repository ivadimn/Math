# %% [markdown]
# 1. Предложить пример функции, не имеющей предела в нуле и в бесконечностях.
#
# (в ячейках Markdown значком "^" обозначается возведение в степень)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# функция не имеющая пределов в 0 и в бесконечностях
x = np.linspace(-6, 6, 201)
y = np.sin(1 / x)
# Out:
# /home/vadim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in true_divide
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/vadim/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in sin
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from pylab import rcParams
rcParams["figure.figsize"] = 12, 6

# %%
plt.plot(x, y)
plt.title("График sin(1 / x)")
plt.grid(True)
plt.show()

# %% [markdown]
# 2. Привести пример функции, не имеющей предела в точке, но определенной в ней.

# %% [markdown]
# 3. Исследовать функцию   f(x) = x^3 - x^2   по плану:
#
# Область задания и область значений.
#
# Нули функции и их кратность.
#
# Отрезки знакопостоянства.
#
# Интервалы монотонности.
#
# Четность функции.
#
# Ограниченность.
#
# Периодичность.

# %%
x = np.linspace(-2, 2, 201)
y = x**2 * (x - 1)

# %%
rcParams["figure.figsize"] = 4, 6
plt.plot(x, y)
plt.title("График x^3 - x^2")
plt.grid(True)
plt.show()

# %% [markdown]
# 1. dom(f) = R
#
# 2. ran(f) = R
#
# 3. x^3 - x^2 = 0 при x = 0 и при x = 1
#
# 4. x^3 - x^2 < 0 при x [-inf, 0) (0, 1),
#    x^3 - x^2 > 0 при x (1, +inf]
#
# 5. y = x^3 - x^2 не является не чётной не нечётной
#
# 6. y = x^3 - x^2 не ограничена
#
# 7. y = x^3 - x^2 не является периодической

# %% [markdown]
# 3. Найти предел:

# %% [markdown]
# 1. lim (3x^3 - 2x^2) / 4x^2; x->0
#
# lim (3x^3 - 2x^2) / 4x^2 = lim x^2(3x - 2)/4x^2 = lim(3x - 2) / 4 = -1/2

# %% [markdown]
# 3. lim ((x + 3) / x)^(4x+1); x->inf
#
# lim ((x + 3) / x)^(4x+1) =
#
# lim (x(1 + 3/x)/x)^(4x+1) =
#
# lim(1 + 3/x)^(4x+1) =
#
# lim(1 + 12/4x)^4x * (1 + 3/x) =
#
# lim(1 + 12/4x)^4x  * lim(1 + 3/x) = e^12 * 1 = e^12

# %% [markdown]
# 4. Тема “Теоремы о пределах”
# найти пределы:

# %% [markdown]
# 1. lim sin(2x)/4x; x->0
#
# lim sin(2x)/4x =
#
# lim 2sin(x)cox(x)/4x =
#
# lim sin(x)/x * cos(x)/2 =
#
# lim sin(x)/x * lim cos(x)/2 = 1/2

# %% [markdown]
# 2. lim (x/sin(x)); x->0
#
# lim (x/sin(x)) =
#
# lim 1 / sin(x)/x =
#
# lim 1 / lim sin(x)/x = 1

# %% [markdown]
# 3. lim x/arcsin(x); x->0
# ### решается аналогично предыдущему
# lim x/arcsin(x) = 1

# %% [markdown]
# 4. lim ((4x + 3) / (4x - 3))^(6x); x->inf
#
# lim ((4x + 3) / (4x - 3))^(6x) = 1
