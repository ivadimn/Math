# %% [markdown]
# Проверить любым способ, является ли данная логическая
# формула тавтологией:
# 1. (𝐴 ∨ 𝐵) → (𝐵 ∨ ^𝐴)
# 2. 𝐴 → (𝐴 ∨ (^𝐵 ∧ 𝐴))
#
# Сформулируйте словесно высказывания:
# 3. (^𝐴 ∨ 𝐵) → ^𝐶
# 4. 𝐶 → (𝐴 ∨ ^𝐵)
#
# А: сегодня светит солнце; В: сегодня сыро; С: я поеду на дачу.

# %% [markdown]
# 1. (𝐴 ∨ 𝐵) → (𝐵 ∨ ^𝐴) - не является тавтологией
# 2. 𝐴 → (𝐴 ∨ (^𝐵 ∧ 𝐴)) - является тавтологией

# %% [markdown]
# 1. (^𝐴 ∨ 𝐵) → ^𝐶 - если сегодня не свети солнце или сегодня сыро, то я не поеду на дачу
# 2. 𝐶 → (𝐴 ∨ ^𝐵) - я поехал на дачу значит сегодня светит солнце или сегодня не сыро

# %% [markdown]
# Математическая логика
#
# Пользуясь  правилом построения противоположного высказывания, записать  утверждения, противоположные следующим:
# 5. На любом курсе каждого факультета есть студенты, сдающие все экзамены на «отлично».
# 6. Каждый студент философского факультета имеет друга,который умеет решать все логические задачи.
# 7. В любом самолете на рейсе Вашингтон-Москва присутствует хотя бы один сотрудник силовых органов, в каждой
# пуговице одежды которого вмонтирован микрофон.

# %% [markdown]
# 5. Есть курс на каком-нибудь фвкультете, где все студенты сдают экзамены не на "отлично"
# 6. Есть студент философского факультета, который не имеет друга, не умеющего решать какую-нибудь логическую задачу.
# 7. Существует самолёт на рейсе Вашингтон-Москва где у всех сотрудников силовых органов есть хотя бы одна пуговица
# в которую не в монтирован микрофон.

# %% [markdown]
# Представить в виде несократимой рациональной дроби
#
# 0.(216)
#
# 1.0(01)

# %%
# 0.(216)
24 / 111
# Out:
# 0.21621621621621623

# %%
# 1.0(01)
991 / 990
# Out:
# 1.001010101010101

# %% [markdown]
# Найдите значение предела
#
# lim (1 / (1 * 2) + 1 / (2 * 3) + 1 / (3 * 4) + ... + 1 / (n - 1) * n)
#
# n->бескон

# %% [markdown]
# lim (1 / (1 * 2) + 1 / (2 * 3) + 1 / (3 * 4) + ... + 1 / (n - 1) * n) =
#
# lim 1/2 * (1 + 1/3 + 1/6 + ... 2 / (n - 1) * n) = 1

# %%
s = 0
for i in range(2, 1000):
    s += 1 / ((i - 1) * i)

print(s)
# Out:
# 0.9989989989989997

# %% [markdown]
# Пользуясь критерием Коши докажите сходимость последовательности
#
# a(n) = sin(1)/2 + sin(2)/4 + sin(3)/8 +...+sin(n)/2^n

# %% [markdown]
# Для доказательства сходимости можно
#
# все синусы в числителях заменить на 1, всё равно самый большой синус = 1
# тогда
#
# a(n) = 1/2 + 1/4 + 1/8 +...+1/2^n это сумма бесконечно убывающей геометрической прогрессии
#
# возмём k = 1
#
# a(n + 1) = 1/2 + 1/4 + 1/8 +...+1/2^n + 1/2^(n+1)
#
# |a(n) - a(n + 1)| = |1/2^(n+1)| = 1/2^n|1/2| < 1/2^n = 1/2^N(eps) = eps
#
# Правда не уверен что так можно....
